# %%
import pandas as pd

# %%
okt = pd.read_csv("2019-Oct-sample.csv")
nop = pd.read_csv("2019-Nov-sample.csv")

# %%
okt.head()
# Out:
#    Unnamed: 0               event_time event_type  product_id  \
# 0           8  2019-10-01 00:00:10 UTC       view    28719074
# 1          17  2019-10-01 00:00:18 UTC       view    10900029
# 2          91  2019-10-01 00:01:17 UTC       view     1004856
# 3         101  2019-10-01 00:01:29 UTC       view     1801551
# 4         103  2019-10-01 00:01:30 UTC       view     3900930
#
#            category_id                        category_code      brand  \
# 0  2053013565480109009                   apparel.shoes.keds      baden
# 1  2053013555069845885             appliances.kitchen.mixer      bosch
# 2  2053013555631882655               electronics.smartphone    samsung
# 3  2053013554415534427                 electronics.video.tv      haier
# 4  2053013552326770905  appliances.environment.water_heater  teploross
#
#     price    user_id                          user_session
# 0  102.71  520571932  ac1cd4e5-a3ce-4224-a2d7-ff660a105880
# ...

# %%
nop.head()
# Out:
#    Unnamed: 0               event_time event_type  product_id  \
# 0          38  2019-11-01 00:00:13 UTC       view     3701016
# 1          52  2019-11-01 00:00:17 UTC       view    43200121
# 2         114  2019-11-01 00:00:42 UTC       view     2700598
# 3         239  2019-11-01 00:01:37 UTC       view     1307519
# 4         241  2019-11-01 00:01:37 UTC       view     1005116
#
#            category_id                     category_code     brand    price  \
# 0  2053013565983425517     appliances.environment.vacuum     tefal   108.09
# 1  2146660887346282824                    apparel.tshirt  goodloot     8.73
# 2  2053013563911439225  appliances.kitchen.refrigerators   indesit   314.08
# 3  2053013558920217191                computers.notebook      acer  1209.55
# 4  2053013555631882655            electronics.smartphone     apple  1013.86
#
#      user_id                          user_session
# 0  566278257  5cafe67a-3c46-4b47-a46a-ab30de4356bc
# ...

# %%
frames=[okt,nop]
result=pd.concat(frames).drop_duplicates().reset_index(drop=True)

# %%
result.head()
# Out:
#    Unnamed: 0               event_time event_type  product_id  \
# 0           8  2019-10-01 00:00:10 UTC       view    28719074
# 1          17  2019-10-01 00:00:18 UTC       view    10900029
# 2          91  2019-10-01 00:01:17 UTC       view     1004856
# 3         101  2019-10-01 00:01:29 UTC       view     1801551
# 4         103  2019-10-01 00:01:30 UTC       view     3900930
#
#            category_id                        category_code      brand  \
# 0  2053013565480109009                   apparel.shoes.keds      baden
# 1  2053013555069845885             appliances.kitchen.mixer      bosch
# 2  2053013555631882655               electronics.smartphone    samsung
# 3  2053013554415534427                 electronics.video.tv      haier
# 4  2053013552326770905  appliances.environment.water_heater  teploross
#
#     price    user_id                          user_session
# 0  102.71  520571932  ac1cd4e5-a3ce-4224-a2d7-ff660a105880
# ...

# %%
z=result[['product_id','category_id','category_code','brand','price']]
z
# Out:
#          product_id          category_id                        category_code  \
# 0          28719074  2053013565480109009                   apparel.shoes.keds
# 1          10900029  2053013555069845885             appliances.kitchen.mixer
# 2           1004856  2053013555631882655               electronics.smartphone
# 3           1801551  2053013554415534427                 electronics.video.tv
# 4           3900930  2053013552326770905  appliances.environment.water_heater
# ...             ...                  ...                                  ...
# 3963804     1005135  2053013555631882655               electronics.smartphone
# 3963805     5701194  2053013553970938175              auto.accessories.player
# 3963806     4803878  2053013554658804075          electronics.audio.headphone
# 3963807     6000094  2053013560807654091               auto.accessories.alarm
# 3963808     3701309  2053013565983425517        appliances.environment.vacuum
#
#              brand    price
# ...

# %%
filter=result.loc[result["event_type"]=='purchase']
filter
# Out:
#          Unnamed: 0               event_time event_type  product_id  \
# 74             1811  2019-10-01 02:20:11 UTC   purchase     4804055
# 113            2798  2019-10-01 02:23:05 UTC   purchase     4802157
# 219            4959  2019-10-01 02:28:09 UTC   purchase     1004856
# 233            5210  2019-10-01 02:28:40 UTC   purchase     1005104
# 250            5654  2019-10-01 02:29:32 UTC   purchase     8800448
# ...             ...                      ...        ...         ...
# 3963602    67495403  2019-11-30 23:19:17 UTC   purchase     1004857
# 3963621    67496006  2019-11-30 23:22:45 UTC   purchase     1004565
# 3963633    67496232  2019-11-30 23:24:09 UTC   purchase     1004566
# 3963700    67498445  2019-11-30 23:38:13 UTC   purchase     1004650
# 3963736    67499872  2019-11-30 23:46:13 UTC   purchase     4804056
#
#                  category_id                category_code    brand   price  \
# ...

# %%
filter[['category','productnm','product_name']]=filter.category_code.str.split(".",expand=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\dewia\OneDrive\Dokumen\Dewi - Pacmann\Tugas - SQL\Dewi_I4Zs_Shell_4\read.ipynb Cell 9 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/dewia/OneDrive/Dokumen/Dewi%20-%20Pacmann/Tugas%20-%20SQL/Dewi_I4Zs_Shell_4/read.ipynb#ch0000009?line=0'>1</a> filter[['category','productnm','product_name']]=filter.category_code.str.split(".",expand=True)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\pandas\core\frame.py:3643, in DataFrame.__setitem__(self, key, value)
#    3641     self._setitem_frame(key, value)
#    3642 elif isinstance(key, (Series, np.ndarray, list, Index)):
# -> 3643     self._setitem_array(key, value)
#    3644 elif isinstance(value, DataFrame):
#    3645     self._set_item_frame_value(key, value)
#
# ...
